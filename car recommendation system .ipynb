# %%
import pandas as pd
import numpy as np

# %%
car_00 = pd.read_csv("Car data 5.csv")

# %%
car_00.head()
# Out:
#                        Brand        Price   mpg  cylinders horsepower  weight
# 0  chevrolet chevelle malibu  25561.59078  18.0          8        130    3504
# 1          buick skylark 320  24221.42273  15.0          8        165    3693
# 2         plymouth satellite  27240.84373  18.0          8        150    3436
# 3              amc rebel sst  33684.96888  16.0          8        150    3433
# 4                ford torino  20000.00000  17.0          8        140    3449

# %%
print("car features : ",car_00.shape)
# Out:
# car features :  (398, 6)

# %%
car_01 = pd.read_csv("Car data 1.csv")

# %%
car_02 = pd.read_csv("Car data 2.csv")

# %%
car_03 = pd.read_csv("Car data 3.csv")

# %%
car_04 = pd.read_csv("Car data 4.csv")

# %%
car_01.head()
# Out:
#      Brand  Year    Price   Kms_Driven Fuel_Type Transmission
# 0     ritz  2014   ? 5.59        27000    Petrol       Manual
# 1      sx4  2013   ? 9.54        43000    Diesel       Manual
# 2     ciaz  2017   ? 9.85         6900    Petrol       Manual
# 3  wagon r  2011   ? 4.15         5200    Petrol       Manual
# 4    swift  2014   ? 6.87        42450    Diesel       Manual

# %%
car_02.head()
# Out:
#                       Brand  Year  kms_Driven Fuel_Type Transmission
# 0             Maruti 800 AC  2007       70000    Petrol       Manual
# 1  Maruti Wagon R LXI Minor  2007       50000    Petrol       Manual
# 2      Hyundai Verna 1.6 SX  2012      100000    Diesel       Manual
# 3    Datsun RediGO T Option  2017       46000    Petrol       Manual
# 4     Honda Amaze VX i-DTEC  2014      141000    Diesel       Manual

# %%
car_03.head()
# Out:
#                 Brand Fuel_Type Transmission  fuel_tank_capacity
# 0     Maruti Alto K10    Petrol    Automatic                27.0
# 1       Maruti Brezza    Petrol    Automatic                48.0
# 2       Mahindra Thar    Diesel    Automatic                57.0
# 3     Mahindra XUV700    Diesel    Automatic                60.0
# 4  Mahindra Scorpio-N    Diesel    Automatic                57.0

# %%
car_04.head()
# Out:
#           Country   Color  Year                  Brand
# 0       Indonesia    Teal   1993        FordClub Wagon
# 1           China  Fuscia   2007  CadillacEscalade ESV
# 2       Indonesia  Orange   2009       MazdaMiata MX-5
# 3           China  Orange   2005                AudiA4
# 4  Czech Republic    Pink   1994          NissanMaxima

# %%
 car_01 = car_01.merge(car_02, how = 'outer')

# %%
car_01.shape
# Out:
# (4540, 7)

# %%
car_01
# Out:
#                                              Brand  Year    Price   \
# 0                                             ritz  2014   ? 5.59
# 1                                              sx4  2013   ? 9.54
# 2                                             ciaz  2017   ? 9.85
# 3                                          wagon r  2011   ? 4.15
# 4                                            swift  2014   ? 6.87
# ...                                            ...   ...       ...
# 4535                  Mahindra Scorpio S2 7 Seater  2015       NaN
# 4536  Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV  2012       NaN
# 4537           Hyundai i20 Magna 1.4 CRDi (Diesel)  2014       NaN
# 4538                    Hyundai i20 Magna 1.4 CRDi  2014       NaN
# 4539                           Maruti 800 AC BSIII  2009       NaN
#
#       Kms_Driven Fuel_Type Transmission  kms_Driven
# 0        27000.0    Petrol       Manual         NaN
# 1        43000.0    Diesel       Manual         NaN
# ...

# %%
 car_01 = car_01.merge(car_03, how = 'outer')

# %%
 car_01
# Out:
#                          Brand    Year    Price   Kms_Driven Fuel_Type  \
# 0                         ritz  2014.0   ? 5.59      27000.0    Petrol
# 1                         ritz  2011.0   ? 4.89      54200.0    Petrol
# 2                         ritz  2013.0   ? 4.89      64532.0    Petrol
# 3                          sx4  2013.0   ? 9.54      43000.0    Diesel
# 4                         ciaz  2017.0   ? 9.85       6900.0    Petrol
# ...                        ...     ...       ...         ...       ...
# 4738             Jeep Meridian     NaN       NaN         NaN    Diesel
# 4739  Mercedes-Benz AMG A 45 S     NaN       NaN         NaN    Petrol
# 4740            MG Hector Plus     NaN       NaN         NaN    Diesel
# 4741                Audi RS Q8     NaN       NaN         NaN    Petrol
# 4742      Maruti Alto 800 tour     NaN       NaN         NaN    Petrol
#
#      Transmission  kms_Driven  fuel_tank_capacity
# 0          Manual         NaN                 NaN
# ...

# %%
 car_01 = car_01.merge(car_04, how = 'outer')

# %%
car_01
# Out:
#                          Brand    Year    Price   Kms_Driven Fuel_Type  \
# 0                         ritz  2014.0   ? 5.59      27000.0    Petrol
# 1                         ritz  2011.0   ? 4.89      54200.0    Petrol
# 2                         ritz  2013.0   ? 4.89      64532.0    Petrol
# 3                         ritz  2012.0   ? 5.98      51439.0    Diesel
# 4                          sx4  2013.0   ? 9.54      43000.0    Diesel
# ...                        ...     ...       ...         ...       ...
# 34738          DaihatsuCharade     NaN       NaN         NaN       NaN
# 34739      LamborghiniReventón     NaN       NaN         NaN       NaN
# 34740      LamborghiniReventón     NaN       NaN         NaN       NaN
# 34741  PontiacGrand Prix Turbo     NaN       NaN         NaN       NaN
# 34742        KiaMohave/Borrego     NaN       NaN         NaN       NaN
#
#       Transmission  kms_Driven  fuel_tank_capacity    Country   Color   Year
# ...

# %%
 car_01 = car_01.merge(car_00, how = 'outer')

# %%
car_01
# Out:
#                  Brand    Year    Price   Kms_Driven Fuel_Type Transmission  \
# 0                 ritz  2014.0   ? 5.59      27000.0    Petrol       Manual
# 1                 ritz  2011.0   ? 4.89      54200.0    Petrol       Manual
# 2                 ritz  2013.0   ? 4.89      64532.0    Petrol       Manual
# 3                 ritz  2012.0   ? 5.98      51439.0    Diesel       Manual
# 4                  sx4  2013.0   ? 9.54      43000.0    Diesel       Manual
# ...                ...     ...       ...         ...       ...          ...
# 35136  ford mustang gl     NaN       NaN         NaN       NaN          NaN
# 35137        vw pickup     NaN       NaN         NaN       NaN          NaN
# 35138    dodge rampage     NaN       NaN         NaN       NaN          NaN
# 35139      ford ranger     NaN       NaN         NaN       NaN          NaN
# 35140       chevy s-10     NaN       NaN         NaN       NaN          NaN
#
# ...

# %%
car_01.to_csv('entire data.csv',index=False)
